# %% [markdown]
# <a href="https://colab.research.google.com/github/VarunSharma02/Pandas_codes/blob/main/Copy_of_Pandas_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = {'Name' : ['Ram', 'Ravi', 'Rakesh', 'Saurabh', 'Raj'],
         'DA':[17, 19, 20, 18, 17],
         'Python':[15,15, 17, 14, 13]}

# %% [markdown]
# Create list of above mention data in list variable name `glucose`

# %%
glucose = [11, 13.8, 23, 22, 45.9, 2.3, 56.3, 23.4, 24, 13]

# %%
import pandas as pd
df = pd.DataFrame(marks)

# %%
df.head()
# Out:
#       Name  DA  Python
# 0      Ram  17      15
# 1     Ravi  19      15
# 2   Rakesh  20      17
# 3  Saurabh  18      14
# 4      Raj  17      13

# %%
df.sum()
# Out:
# Name      RamRaviRakeshSaurabhRaj
# DA                             91
# Python                         74
# dtype: object

# %%
df.DA.sum()
# Out:
# 91

# %%
df['DA'].sum()
# Out:
# 91

# %%
df.iloc[:,1:3]
# Out:
#    DA  Python
# 0  17      15
# 1  19      15
# 2  20      17
# 3  18      14
# 4  17      13

# %%
df.loc[:,['DA','Python']]
# Out:
#    DA  Python
# 0  17      15
# 1  19      15
# 2  20      17
# 3  18      14
# 4  17      13

# %%
df.iloc[:,1:3].sum()
# Out:
# DA        91
# Python    74
# dtype: int64

# %%
df.iloc[:,1:3].sum(axis = 1)
# Out:
# 0    32
# 1    34
# 2    37
# 3    32
# 4    30
# dtype: int64

# %%
df['Total']=df.iloc[:,1:3].sum(axis = 1)

# %%
df
# Out:
#       Name  DA  Python  Total
# 0      Ram  17      15     32
# 1     Ravi  19      15     34
# 2   Rakesh  20      17     37
# 3  Saurabh  18      14     32
# 4      Raj  17      13     30

# %%
df['DA']
# Out:
# 0    17
# 1    19
# 2    20
# 3    18
# 4    17
# Name: DA, dtype: int64

# %%
df['cum_sum'] = df['DA'].cumsum()

# %%
df
# Out:
#       Name  DA  Python  Total  cum_sum
# 0      Ram  17      15     32       17
# 1     Ravi  19      15     34       36
# 2   Rakesh  20      17     37       56
# 3  Saurabh  18      14     32       74
# 4      Raj  17      13     30       91

# %%
df['DA'].unique()
# Out:
# array([17, 19, 20, 18])

# %%
import numpy as np
np.sort(df['DA'].unique())
# Out:
# array([17, 18, 19, 20])

# %%
df
# Out:
#       Name  DA  Python  Total  cum_sum
# 0      Ram  17      15     32       17
# 1     Ravi  19      15     34       36
# 2   Rakesh  20      17     37       56
# 3  Saurabh  18      14     32       74
# 4      Raj  17      13     30       91

# %%
df.sort_values('Name')
# Out:
#       Name  DA  Python  Total  cum_sum
# 4      Raj  17      13     30       91
# 2   Rakesh  20      17     37       56
# 0      Ram  17      15     32       17
# 1     Ravi  19      15     34       36
# 3  Saurabh  18      14     32       74

# %%
df.iloc[:,1:3].sum(axis = 0)
# Out:
# DA        91
# Python    74
# dtype: int64

# %%
subset  = df.iloc[:,1:3]

# %%
subset
# Out:
#    DA  Python
# 0  17      15
# 1  19      15
# 2  20      17
# 3  18      14
# 4  17      13

# %%
subset.idxmax()
# Out:
# DA        2
# Python    2
# dtype: int64

# %%
subset.max()
# Out:
# DA        20
# Python    17
# dtype: int64

# %%
subset.min()
# Out:
# DA        17
# Python    13
# dtype: int64

# %%
subset.iloc[subset['DA'].idxmax(),:]
# Out:
# DA        20
# Python    17
# Name: 2, dtype: int64

# %%
subset.count()
# Out:
# DA        5
# Python    5
# dtype: int64

# %%
subset['DA']
# Out:
# 0    17
# 1    19
# 2    20
# 3    18
# 4    17
# Name: DA, dtype: int64

# %%
df
# Out:
#       Name  DA  Python  Total  cum_sum
# 0      Ram  17      15     32       17
# 1     Ravi  19      15     34       36
# 2   Rakesh  20      17     37       56
# 3  Saurabh  18      14     32       74
# 4      Raj  17      13     30       91

# %%
df.iloc[1, :]
# Out:
# Name       Ravi
# DA           19
# Python       15
# Total        34
# cum_sum      36
# Name: 1, dtype: object

# %%
df.iloc[1, 0]
# Out:
# 'Ravi'

# %%
df.iloc

# %%
glucose = [11,	13.8,	23,	22,	45.9,	2.3,	56.3,	23.4,	24,	13]

# %%
glucose
# Out:
# [11, 13.8, 23, 22, 45.9, 2.3, 56.3, 23.4, 24, 13]

# %%
import numpy as np
np.max(glucose)
# Out:
# 56.3
