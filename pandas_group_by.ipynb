# %% [markdown]
# <a href="https://colab.research.google.com/github/VarunSharma02/Pandas_codes/blob/main/pandas_group_by.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Pandas Group By</font>

# %% [markdown]
# **In this tutorial we are going to look at weather data from various cities and see how group by can be used to run some analytics.**

# %%
# !wget "https://raw.githubusercontent.com/pradhrahul/data_analytics/main/student1.csv"
# Out:
# --2024-05-04 05:10:48--  https://raw.githubusercontent.com/pradhrahul/data_analytics/main/student1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 125 [text/plain]
# Saving to: ‘student1.csv’
#
# student1.csv        100%[===================>]     125  --.-KB/s    in 0s
#
# 2024-05-04 05:10:48 (1.85 MB/s) - ‘student1.csv’ saved [125/125]

# %%
# !wget "https://raw.githubusercontent.com/pradhrahul/data_analytics/main/student2.csv"
# Out:
# --2024-05-04 05:10:48--  https://raw.githubusercontent.com/pradhrahul/data_analytics/main/student2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163 [text/plain]
# Saving to: ‘student2.csv’
#
# student2.csv        100%[===================>]     163  --.-KB/s    in 0s
#
# 2024-05-04 05:10:48 (1.32 MB/s) - ‘student2.csv’ saved [163/163]

# %%
# !wget "https://raw.githubusercontent.com/pradhrahul/data_analytics/main/student3.csv"
# Out:
# --2024-05-04 05:10:49--  https://raw.githubusercontent.com/pradhrahul/data_analytics/main/student3.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189 [text/plain]
# Saving to: ‘student3.csv’
#
# student3.csv        100%[===================>]     189  --.-KB/s    in 0s
#
# 2024-05-04 05:10:49 (2.18 MB/s) - ‘student3.csv’ saved [189/189]

# %%
import pandas as pd
student1 = pd.read_csv("student1.csv",na_values = [" "])
student2 = pd.read_csv("student2.csv")
student3 = pd.read_csv("student3.csv")

# %%
student1
# Out:
#    sid  sname  gpa  sizehs
# 0  123    Amy  3.9    1000
# 1  234    Bob  3.6    1500
# 2  320   Lori  NaN    2500
# 3  345  Craig  3.5     500
# 4  432  Kevin  NaN    1500
# 5  456  Doris  3.9    1000

# %%
student2
# Out:
#    sid   sname  gpa  sizehs
# 0  543   Craig  3.4    2000
# 1  567  Edward  2.9    2000
# 2  654     Amy  3.9    1000
# 3  678     Fay  3.8     200
# 4  765     Jay  2.9    1500
# 5  789    Gary  3.4     800
# 6  876   Irene  3.9     400
# 7  987   Helen  3.7     800

# %%
student = pd.concat([student1, student2], axis = "rows", ignore_index = True)
student
# Out:
#     sid   sname  gpa  sizehs
# 0   123     Amy  3.9    1000
# 1   234     Bob  3.6    1500
# 2   320    Lori  NaN    2500
# 3   345   Craig  3.5     500
# 4   432   Kevin  NaN    1500
# 5   456   Doris  3.9    1000
# 6   543   Craig  3.4    2000
# 7   567  Edward  2.9    2000
# 8   654     Amy  3.9    1000
# 9   678     Fay  3.8     200
# 10  765     Jay  2.9    1500
# 11  789    Gary  3.4     800
# 12  876   Irene  3.9     400
# 13  987   Helen  3.7     800

# %%
student3
# Out:
#            dob sex
# 0   2005-12-11   F
# 1   2006-08-28   M
# 2   2006-03-06   F
# 3   2005-06-06   M
# 4   2006-08-26   M
# 5   2006-04-17   F
# 6   2006-02-25   M
# 7   2005-05-29   M
# 8   2006-05-22   F
# 9   2006-12-06   F
# 10  2005-12-13   M
# 11  2005-02-16   M
# 12  2005-08-06   F
# 13  2005-12-27   F

# %%
student = pd.concat([student, student3], axis = "columns")

# %%
student
# Out:
#     sid   sname  gpa  sizehs         dob sex
# 0   123     Amy  3.9    1000  2005-12-11   F
# 1   234     Bob  3.6    1500  2006-08-28   M
# 2   320    Lori  NaN    2500  2006-03-06   F
# 3   345   Craig  3.5     500  2005-06-06   M
# 4   432   Kevin  NaN    1500  2006-08-26   M
# 5   456   Doris  3.9    1000  2006-04-17   F
# 6   543   Craig  3.4    2000  2006-02-25   M
# 7   567  Edward  2.9    2000  2005-05-29   M
# 8   654     Amy  3.9    1000  2006-05-22   F
# 9   678     Fay  3.8     200  2006-12-06   F
# 10  765     Jay  2.9    1500  2005-12-13   M
# 11  789    Gary  3.4     800  2005-02-16   M
# 12  876   Irene  3.9     400  2005-08-06   F
# 13  987   Helen  3.7     800  2005-12-27   F

# %%
# !wget "https://raw.githubusercontent.com/pradhrahul/data_analytics/main/apply.csv"
# !wget "https://raw.githubusercontent.com/pradhrahul/data_analytics/main/college.csv"
# Out:
# --2024-05-04 05:10:50--  https://raw.githubusercontent.com/pradhrahul/data_analytics/main/apply.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 471 [text/plain]
# Saving to: ‘apply.csv’
#
# apply.csv           100%[===================>]     471  --.-KB/s    in 0s
#
# 2024-05-04 05:10:50 (20.7 MB/s) - ‘apply.csv’ saved [471/471]
#
# --2024-05-04 05:10:50--  https://raw.githubusercontent.com/pradhrahul/data_analytics/main/college.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# ...

# %%
college = pd.read_csv("college.csv",header=None)
college
# Out:
#           0   1      2
# 0  Berkeley  CA  36000
# 1   Cornell  NY  21000
# 2   UAustin  TX  25000
# 3       MIT  MA  10000
# 4  Stanford  CA  15000

# %%
student
# Out:
#     sid   sname  gpa  sizehs         dob sex
# 0   123     Amy  3.9    1000  2005-12-11   F
# 1   234     Bob  3.6    1500  2006-08-28   M
# 2   320    Lori  NaN    2500  2006-03-06   F
# 3   345   Craig  3.5     500  2005-06-06   M
# 4   432   Kevin  NaN    1500  2006-08-26   M
# 5   456   Doris  3.9    1000  2006-04-17   F
# 6   543   Craig  3.4    2000  2006-02-25   M
# 7   567  Edward  2.9    2000  2005-05-29   M
# 8   654     Amy  3.9    1000  2006-05-22   F
# 9   678     Fay  3.8     200  2006-12-06   F
# 10  765     Jay  2.9    1500  2005-12-13   M
# 11  789    Gary  3.4     800  2005-02-16   M
# 12  876   Irene  3.9     400  2005-08-06   F
# 13  987   Helen  3.7     800  2005-12-27   F

# %%
apply = pd.read_csv("apply.csv")
apply
# Out:
#     sid     cname           major decision
# 0   123  Berkeley              CS        t
# 1   123   Cornell              EE        t
# 2   123  Stanford              CS        t
# 3   123  Stanford              EE        f
# 4   234  Berkeley         biology        f
# 5   321       MIT         history        f
# 6   321       MIT      psychology        t
# 7   345   Cornell  bioengineering        f
# 8   345   Cornell              CS        t
# 9   345   Cornell              EE        f
# 10  345       MIT  bioengineering        t
# 11  543       MIT              CS        f
# 12  678  Stanford         history        t
# 13  765   Cornell         history        f
# 14  765   Cornell      psychology        t
# 15  765  Stanford         history        t
# 16  876       MIT         biology        t
# 17  876       MIT  marine biology        f
# 18  876  Stanford              CS        f
# 19  987  Berkeley              CS        t
# 20  987  Stanford              CS        t

# %%
pd.merge(student, apply, on= "sid", how = "inner")
# Out:
#     sid  sname  gpa  sizehs         dob sex     cname           major decision
# 0   123    Amy  3.9    1000  2005-12-11   F  Berkeley              CS        t
# 1   123    Amy  3.9    1000  2005-12-11   F   Cornell              EE        t
# 2   123    Amy  3.9    1000  2005-12-11   F  Stanford              CS        t
# 3   123    Amy  3.9    1000  2005-12-11   F  Stanford              EE        f
# 4   234    Bob  3.6    1500  2006-08-28   M  Berkeley         biology        f
# 5   345  Craig  3.5     500  2005-06-06   M   Cornell  bioengineering        f
# 6   345  Craig  3.5     500  2005-06-06   M   Cornell              CS        t
# 7   345  Craig  3.5     500  2005-06-06   M   Cornell              EE        f
# 8   345  Craig  3.5     500  2005-06-06   M       MIT  bioengineering        t
# 9   543  Craig  3.4    2000  2006-02-25   M       MIT              CS        f
# 10  678    Fay  3.8     200  2006-12-06   F  Stanford         history        t
# ...

# %%
pd.merge(student, apply, on = "sid", how = "right")
# Out:
#     sid  sname  gpa  sizehs         dob  sex     cname           major  \
# 0   123    Amy  3.9  1000.0  2005-12-11    F  Berkeley              CS
# 1   123    Amy  3.9  1000.0  2005-12-11    F   Cornell              EE
# 2   123    Amy  3.9  1000.0  2005-12-11    F  Stanford              CS
# 3   123    Amy  3.9  1000.0  2005-12-11    F  Stanford              EE
# 4   234    Bob  3.6  1500.0  2006-08-28    M  Berkeley         biology
# 5   321    NaN  NaN     NaN         NaN  NaN       MIT         history
# 6   321    NaN  NaN     NaN         NaN  NaN       MIT      psychology
# 7   345  Craig  3.5   500.0  2005-06-06    M   Cornell  bioengineering
# 8   345  Craig  3.5   500.0  2005-06-06    M   Cornell              CS
# 9   345  Craig  3.5   500.0  2005-06-06    M   Cornell              EE
# 10  345  Craig  3.5   500.0  2005-06-06    M       MIT  bioengineering
# 11  543  Craig  3.4  2000.0  2006-02-25    M       MIT              CS
# ...

# %%
# !wget "https://raw.githubusercontent.com/codebasics/py/master/pandas/7_group_by/weather_by_cities.csv"
# Out:
# --2024-05-04 05:10:51--  https://raw.githubusercontent.com/codebasics/py/master/pandas/7_group_by/weather_by_cities.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 367 [text/plain]
# Saving to: ‘weather_by_cities.csv’
#
# weather_by_cities.c 100%[===================>]     367  --.-KB/s    in 0s
#
# 2024-05-04 05:10:51 (5.38 MB/s) - ‘weather_by_cities.csv’ saved [367/367]

# %%
import pandas as pd
df = pd.read_csv("weather_by_cities.csv", parse_dates = ["day"])
df
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28         12    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         20   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          12 non-null     datetime64[ns]
#  1   city         12 non-null     object
#  2   temperature  12 non-null     int64
#  3   windspeed    12 non-null     int64
#  4   event        12 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 608.0+ bytes

# %%
df["event"] = df["event"].astype("category")
df["city"] = df["city"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          12 non-null     datetime64[ns]
#  1   city         12 non-null     category
#  2   temperature  12 non-null     int64
#  3   windspeed    12 non-null     int64
#  4   event        12 non-null     category
# dtypes: category(2), datetime64[ns](1), int64(2)
# memory usage: 784.0 bytes

# %% [markdown]
# ### For this dataset, get following answers,
# #### 1. What was the maximum temperature in each of these 3 cities?
# #### 2. What was the average windspeed in each of these 3 cities?

# %% [markdown]
# Pandas dataframe.groupby() function is used to split the data into groups based on some criteria.
# It is used for grouping the data according to the categories and applying a function to the categories. It also helps to aggregate data efficiently.

# %%
df
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28         12    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         20   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
g = df.groupby("city")
g.first()
# Out:
#                 day  temperature  windspeed  event
# city
# mumbai   2017-01-01           90          5  Sunny
# new york 2017-01-01           32          6   Rain
# paris    2017-01-01           45         20  Sunny

# %% [markdown]
# **DataFrameGroupBy object looks something like below,**

# %% [markdown]
# <img src="https://github.com/codebasics/py/blob/master/pandas/7_group_by/group_by_cities.png?raw=1">

# %%
for city, data in g:
    print("city:",city)
    print("\n")
    print("data:",data)
# Out:
# city: mumbai
#
#
# data:          day    city  temperature  windspeed  event
# 4 2017-01-01  mumbai           90          5  Sunny
# 5 2017-01-02  mumbai           85         12    Fog
# 6 2017-01-03  mumbai           87         15    Fog
# 7 2017-01-04  mumbai           92          5   Rain
# city: new york
#
#
# data:          day      city  temperature  windspeed  event
# 0 2017-01-01  new york           32          6   Rain
# 1 2017-01-02  new york           36          7  Sunny
# 2 2017-01-03  new york           28         12   Snow
# 3 2017-01-04  new york           33          7  Sunny
# city: paris
#
#
# data:           day   city  temperature  windspeed   event
# 8  2017-01-01  paris           45         20   Sunny
# 9  2017-01-02  paris           50         13  Cloudy
# 10 2017-01-03  paris           54          8  Cloudy
# 11 2017-01-04  paris           42         10  Cloudy

# %% [markdown]
# **This is similar to SQL,**
#
# **SELECT * from weather_data GROUP BY city**

# %%
g.get_group('mumbai')
# Out:
#          day    city  temperature  windspeed  event
# 4 2017-01-01  mumbai           90          5  Sunny
# 5 2017-01-02  mumbai           85         12    Fog
# 6 2017-01-03  mumbai           87         15    Fog
# 7 2017-01-04  mumbai           92          5   Rain

# %%
df.groupby("city")["temperature"].max()
# Out:
# city
# mumbai      92
# new york    36
# paris       54
# Name: temperature, dtype: int64

# %%
df.groupby("city")["temperature"].mean()
# Out:
# city
# mumbai      88.50
# new york    32.25
# paris       47.75
# Name: temperature, dtype: float64

# %%
df.groupby("city")["temperature"].describe()
# Out:
#           count   mean       std   min    25%   50%    75%   max
# city
# mumbai      4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york    4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris       4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0

# %% [markdown]
# **This method of splitting your dataset in smaller groups and then applying an operation
# (such as min or max) to get aggregate result is called Split-Apply-Combine. It is illustrated in a diagram below**

# %% [markdown]
# <img src="https://github.com/codebasics/py/blob/master/pandas/7_group_by/split_apply_combine.png?raw=1">

# %%
g.describe()
# Out:
#            day                                                                 \
#          count                 mean                  min                  25%
# city
# mumbai       4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
# new york     4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
# paris        4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
#
#                                                                               \
#                           50%                  75%                  max  std
# city
# mumbai    2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
# new york  2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
# paris     2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
#
#          temperature         ...                 windspeed                    \
#                count   mean  ...   max       std     count   mean  min   25%
# ...

# %%
g.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
g.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      Axes(0.125,0.11;0.775x0.77)
# new york    Axes(0.125,0.11;0.775x0.77)
# paris       Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# <h4>Group data using custom function: Let's say you want to group your data using custom function. Here the requirement is to create three groups<h4>
# <ol>
#     <li>Days when temperature was between 80 and 90</li>
#     <li>Days when it was between 50 and 60</li>
#     <li>Days when it was anything else</li>
# </ol>

# %% [markdown]
# For this you need to write custom grouping function and pass that to groupby

# %%
def grouper(df, idx, col):
    if 80 <= df[col].loc[idx] <= 90:
        return '80-90'
    elif 50 <= df[col].loc[idx] <= 60:
        return '50-60'
    else:
        return 'others'

# %%
g = df.groupby(lambda x: grouper(df, x, 'temperature'))
g

# %%
for key, d in g:
    print("Group by Key: {}\n".format(key))
    print(d)
# Out:
# Group by Key: 50-60
#
#           day   city  temperature  windspeed   event
# 9  2017-01-02  paris           50         13  Cloudy
# 10 2017-01-03  paris           54          8  Cloudy
# Group by Key: 80-90
#
#          day    city  temperature  windspeed  event
# 4 2017-01-01  mumbai           90          5  Sunny
# 5 2017-01-02  mumbai           85         12    Fog
# 6 2017-01-03  mumbai           87         15    Fog
# Group by Key: others
#
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28         12    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         20   Sunny
# 11 2017-01-04     paris           42         10  Cloudy
