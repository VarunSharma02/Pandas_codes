# %% [markdown]
# <a href="https://colab.research.google.com/github/VarunSharma02/Pandas_codes/blob/main/pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={"Emp_code":['E1','E2','E3','E4','E5'],"Emp_name":['Amit', 'Aman', 'Jay', 'Vikram', 'Vinit'],"Salary":[1000, 2000, 1500, 2300, 700]}

# %%
employee=pd.DataFrame(data)
employee
# Out:
#   Emp_code Emp_name  Salary
# 0       E1     Amit    1000
# 1       E2     Aman    2000
# 2       E3      Jay    1500
# 3       E4   Vikram    2300
# 4       E5    Vinit     700

# %%
#3.	Display data of only amit.
employee.loc[0]
# Out:
# Emp_code      E1
# Emp_name    Amit
# Salary      1000
# Name: 0, dtype: object

# %%
#4.	Add index to this DataFrame as ['HR', 'Fin', 'Fin', 'Mkt', 'Opr']
employee[""]=['HR', 'Fin', 'Fin', 'Mkt', 'Opr']
employee
# Out:
#   Emp_code Emp_name  Salary
# 0       E1     Amit    1000   HR
# 1       E2     Aman    2000  Fin
# 2       E3      Jay    1500  Fin
# 3       E4   Vikram    2300  Mkt
# 4       E5    Vinit     700  Opr

# %%
#5.	Display first five rows
employee.head()
# Out:
#   Emp_code Emp_name  Salary
# 0       E1     Amit    1000   HR
# 1       E2     Aman    2000  Fin
# 2       E3      Jay    1500  Fin
# 3       E4   Vikram    2300  Mkt
# 4       E5    Vinit     700  Opr

# %%
#6.	Display data of row 3,4 only
employee.iloc[3:5]
# Out:
#   Emp_code Emp_name  Salary
# 3       E4   Vikram    2300  Mkt
# 4       E5    Vinit     700  Opr

# %%
#7.	Display only salary of 3,4 rows
employee.iloc[3:5,2]
# Out:
# 3    2300
# 4     700
# Name: Salary, dtype: int64

# %%
#8.	Display data of column index 1 of row 3,4.
employee.iloc[3:5,1]
# Out:
# 3    Vikram
# 4     Vinit
# Name: Emp_name, dtype: object

# %%
#9.	Display data of ‘HR’ and ‘Mkt’
employee.iloc[[0,3]]
# Out:
#   Emp_code Emp_name  Salary        HRA
# 0       E1     Amit    1100   HR  None
# 3       E4   Vikram    2400  Mkt  None

# %%
#10.	Display only salary of ‘HR’ and ‘Mkt’.
employee.iloc[[0,3],2:3]
# Out:
#    Salary
# 0    1100
# 3    2400

# %%
#11.	Display only salary of all employees.
employee.iloc[:,2]
# Out:
# 0    1000
# 1    2000
# 2    1500
# 3    2300
# 4     700
# Name: Salary, dtype: int64

# %%
#12.	Find maximum salary.
employee["Salary"].max()
# Out:
# 2300

# %%
employee
# Out:
#   Emp_code Emp_name  Salary
# 0       E1     Amit    1000   HR
# 1       E2     Aman    2000  Fin
# 2       E3      Jay    1500  Fin
# 3       E4   Vikram    2300  Mkt
# 4       E5    Vinit     700  Opr

# %%
#13.	Find index of max salary.
employee["Salary"].idxmax()
# Out:
# 3

# %%
#14.	Display complete row of employee having max salary.
employee.iloc[3,:]
# Out:
# Emp_code        E4
# Emp_name    Vikram
# Salary        2300
#                Mkt
# Name: 3, dtype: object

# %%
#15.	Add 100 to salary of all employees
employee["Salary"]+=100
employee
# Out:
#   Emp_code Emp_name  Salary
# 0       E1     Amit    1100   HR
# 1       E2     Aman    2100  Fin
# 2       E3      Jay    1600  Fin
# 3       E4   Vikram    2400  Mkt
# 4       E5    Vinit     800  Opr

# %%
#16.	Display employee having salary greater than 1500.
employee[employee["Salary"]>1500]
# Out:
#   Emp_code Emp_name  Salary
# 1       E2     Aman    2100  Fin
# 2       E3      Jay    1600  Fin
# 3       E4   Vikram    2400  Mkt

# %%
#17.	Add column HRA with value None
employee["HRA"]=None
employee
# Out:
#   Emp_code Emp_name  Salary        HRA
# 0       E1     Amit    1100   HR  None
# 1       E2     Aman    2100  Fin  None
# 2       E3      Jay    1600  Fin  None
# 3       E4   Vikram    2400  Mkt  None
# 4       E5    Vinit     800  Opr  None
